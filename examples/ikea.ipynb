# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from local.steps import LocalScraperAI
from IPython import display

# %%
url = 'https://www.ikea.com/de/de/p/blahaj-stoffspielzeug-babyhai-20540663/'

# %%
scraper = LocalScraperAI(url)

# %%
print(scraper.step1())
# Out:
# (<WebpageType.DETAILS: 'detailed_page'>, Pagination(type='scroll', xpath=None, url_param=None, url_param_first_value=1), None)

# %%
scraper.parser.total_cost
# Out:
# 0.01706

# %%
display.HTML(scraper.ipython_screenshot)
# Out:
# <img width=400 src="data:image/png;base64,..." />

# %%
scraper.step2()
# Out:
# Static fields (10):
#     name                    xpath                                                                                                                                                                  value
#  0  Product Name            //span[@class='pip-header-section__title--big notranslate']/text()                                                                                                     BLÅHAJ
#  1  Product Description     //span[@class='pip-header-section__description-text']/text()                                                                                                           ['Stoffspielzeug, Babyhai,', 'Stoffspielzeug', 'Stoffspielzeug', 'Teppich Kurzflor', 'Stoffspielzeug', 'Stofftier', 'Stoffspielzeug', 'Stoffspielzeug', 'Stoffspielzeug', 'Stoffspielzeug', 'Stoffspielzeug', 'Stoffspielzeug', 'Baldachin', 'Kissenbezug', 'Stoffspielzeug', 'Stoffspielzeug', 'Bett umbaufähig', 'Stofftier mit LED-Nachtlicht', 'Stoffspielzeug', 'Kissen', 'Stoffspielzeug', 'Bettgest.m Federholzrahmen ausz.', 'Wandleuchte, LED', 'Stoffspielzeug', 'Bettwäsche-Set, 2-teilig', 'Bett umbaufähig', 'Kissenbezug', 'Bettwäsche-Set, 2-teilig', 'Stoffspielzeug', 'Stoffspielzeug', 'Wandleuchte, LED', 'Eckbettsofa mit Bettkasten', 'Stoffspielzeug', 'Beistelltisch mit Rollen', 'Stofftier mit LED-Nachtlicht', 'Wandleuchte, LED', 'Stofftier-Set, 5-teilig', 'Wandaufbewahrung', 'Aufbewahrung mit Boxen', 'Tischleuchte, LED', 'Stoffspielzeug', 'Stofftier', 'Stofftier', 'Stoffspielzeug', 'Stofftier', 'Eckbettsofa mit Bettkasten', 'Beistelltisch mit Rollen', 'Stoffspielzeug', 'Baldachin', 'Stoffspielzeug', 'Bettwäsche-Set, 2-teilig', 'Bett umbaufähig', 'Eckbettsofa mit Bettkasten', 'Stoffspielzeug', 'Beistelltisch mit Rollen', 'Stoffspielzeug', 'Stoffspielzeug', 'Stoffspielzeug', 'Teppich Kurzflor', 'Teppich Kurzflor', 'Aufbewahrungskombi', 'Stoffspielzeug', 'Teppich', 'Bett umbaufähig', 'Stofftier']
#  2  Product Size            //button[@class='pip-link-button pip-header-section__description-measurement']/text()                                                                                  55 cm
#  3  Current Price           //div[@class='pip-temp-price-module__current-price']/span/span[@class='pip-temp-price__nowrap']/span[@class='pip-temp-price__integer']/text()
#  4  Price Decimal           //div[@class='pip-temp-price-module__current-price']/span/span[@class='pip-temp-price__decimal']/span[@class='pip-temp-price__separator']/following-sibling::text()
#  5  Currency                //div[@class='pip-temp-price-module__current-price']/span/span[@class='pip-temp-price__currency']/text()
#  6  Previous Price          //div[@class='pip-temp-price-module__addons']/div/span/span/span[@class='pip-temp-price__nowrap']/span[@class='pip-temp-price__integer']/text()
#  7  Previous Price Decimal  //div[@class='pip-temp-price-module__addons']/div/span/span/span[@class='pip-temp-price__decimal']/span[@class='pip-temp-price__separator']/following-sibling::text()
#  8  Product Summary         //p[@class='pip-product-summary__description']/text()                                                                                                                  Babyhaie lernen schnell, unabhängig zu sein und für sich selbst zu sorgen. Dein Kind braucht dafür etwas länger, aber mit diesem weichen Freund fühlt sich jeder Tag der Entwicklung und des Lernens ein bisschen sicherer an.
#  9  Article Number          //span[@class='pip-product-identifier__value']/text()                                                                                                                  ['205.406.63', '205.406.63']
#
# Dynamic fields (0):
# Not found

# %%
scraper.parser.total_cost
# Out:
# 0.0294

# %%
display.HTML(scraper.ipython_screenshot)
# Out:
# <img width=400 src="data:image/png;base64,..." />

# %%
scraper.crawler.driver.quit()
