# %%
# %load_ext autoreload
# %autoreload 2

# %%
from local.steps import LocalScraperAI

# %%
url = 'https://www.ikea.com/de/de/p/blahaj-stoffspielzeug-babyhai-20540663/'
scraper = LocalScraperAI(url)

# %%
scraper.step1()
print(scraper.summary)
scraper.ipython_screenshot
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# Summary:
# Start url             https://www.ikea.com/de/de/p/blahaj-stoffspielzeug-babyhai-20540663/
# Page Type             WebpageType.DETAILS
# Pagination            Pagination using button with xpath: //*[@class='pip-btn pip-btn--emphasised pip-btn--fluid']
# Total OpenAI cost, $  0.272
# <img width=600 src="data:image/png;base64,..." />

# %%
scraper.step2()
scraper.ipython_screenshot
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# <img width=600 src="data:image/png;base64,..." />

# %%
print(scraper.summary)
# Out:
# Summary:
# Start url             https://www.ikea.com/de/de/p/blahaj-stoffspielzeug-babyhai-20540663/
# Page Type             WebpageType.DETAILS
# Pagination            Pagination using button with xpath: //*[@class='pip-btn pip-btn--emphasised pip-btn--fluid']
# Fields                11 static, 0 dynamic
# Total OpenAI cost, $  0.669

# %%
scraper.static_fields_df
# Out:
#                                   name  \
# 0                         Product Name
# 1                  Product Description
# 2                        Product Price
# 3                     Product Currency
# 4               Product Previous Price
# 5                       Product Length
# 6                     Product Material
# 7            Product Care Instructions
# 8           Product Safety Information
# 9                      Product Reviews
# 10  Product Sustainability Information
#
#                                                 xpath  \
# 0   //div[@class='pip-temp-price-module__name']/sp...
# 1   //div[@class='pip-product-summary']/p[@class='...
# 2   //div[@class='pip-temp-price-module__primary-c...
# 3   //div[@class='pip-temp-price-module__primary-c...
# 4   //div[@class='pip-temp-price-module__addons']/...
# 5   //div[@class='pip-product-dimensions__dimensio...
# 6   //div[@id='SEC_HIDDEN_product-details-material...
# 7   //div[@id='SEC_HIDDEN_product-details-material...
# 8   //div[@id='SEC_HIDDEN_product-details-safety-a...
# 9   //div[@class='pip-product-reviews__reviews']/d...
# 10          //div[@class='pip-pip-long-text__body']/p
#
#                                                 value
# 0                                              BLÅHAJ
# 1   Babyhaie lernen schnell, unabhängig zu sein un...
# 2                                                None
# 3                                                   €
# 4                                                None
# 5                                        Länge: 55 cm
# 6                                                None
# 7   [Feinwäsche, max. 40°C., Nicht mit Chlor bleic...
# 8   [Empfohlen ab 12 Monaten., Das Produkt ist mit...
# 9   [Sehr gut, 100/10, 👍🏻, Sehr süß, ordentlich ve...
# 10  [Wir wollen den Anteil an Neumaterial in unser...

# %%
scraper.crawler.driver.quit()
