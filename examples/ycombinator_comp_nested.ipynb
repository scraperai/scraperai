# %%
# %load_ext autoreload
# %autoreload 2

# %%
from local.steps import LocalScraperAI

# %%
url = 'https://www.ycombinator.com/companies'
scraper = LocalScraperAI(url)

# %%
scraper.step1()
print(scraper.summary)
scraper.ipython_screenshot
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# Summary:
# Start url             https://www.ycombinator.com/companies
# Page Type             WebpageType.CATALOG
# Pagination            Pagination using button with xpath: //div[text()='Loading more...']
# Catalog Item          (card_xpath=//a[contains(@class, '_company_99gj3_339')], url_xpath=//a[contains(@class, '_company_99gj3_339')]/@href)
# Total OpenAI cost, $  0.166
# <img width=600 src="data:image/png;base64,..." />

# %%
scraper.step2(with_nested=True)
print(scraper.summary)
scraper.ipython_screenshot
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# Summary:
# Start url             https://www.ycombinator.com/companies
# Page Type             WebpageType.CATALOG
# Pagination            Pagination using button with xpath: //button[text()='Show 1,000+ companies']
# Catalog Item          (card_xpath=//a[contains(@class, '_company_99gj3_339')], url_xpath=//a[contains(@class, '_company_99gj3_339')]/@href)
# Fields                18 static, 0 dynamic
# Total OpenAI cost, $  0.684
# <img width=600 src="data:image/png;base64,..." />

# %%
scraper.static_fields_df
# Out:
#                      name                                              xpath  \
# 0            Company Name          //h1[contains(@class, 'font-extralight')]
# 1         Company Tagline                 //div[contains(@class, 'text-xl')]
# 2     Company Description  //section[contains(@class, 'border-retro-secti...
# 3         Company Website  //div[contains(@class, 'group')]//a[contains(@...
# 4           Company Batch  //a[contains(@href, '/companies?batch=W09')]/d...
# 5          Company Status  //div[contains(@class, 'yc-tw-Pill') and conta...
# 6      Company Industries    //a[contains(@href, '/companies/industry')]/div
# 7        Company Location  //a[contains(@href, '/companies/location/san-f...
# 8   Company Founding Year  //div[contains(text(), 'Founded:')]/following-...
# 9       Company Team Size  //div[contains(text(), 'Team Size:')]/followin...
# 10       Company LinkedIn  //a[contains(@href, 'linkedin') and contains(@...
# 11        Company Twitter  //a[contains(@href, 'twitter') and contains(@c...
# 12       Company Facebook  //a[contains(@href, 'facebook') and contains(@...
# 13     Company Crunchbase  //a[contains(@href, 'crunchbase') and contains...
# 14        Active Founders  //section[contains(@class, 'border-retro-secti...
# 15   Founder Descriptions  //section[contains(@class, 'border-retro-secti...
# 16       Founder LinkedIn  //section[contains(@class, 'border-retro-secti...
# 17        Founder Twitter  //section[contains(@class, 'border-retro-secti...
#
#                                                 value
# 0                                              Airbnb
# 1               Book accommodations around the world.
# 2   [Founded in August of 2008 and based in San Fr...
# 3                                   http://airbnb.com
# 4                                                None
# 5                                                None
# 6                               [marketplace, travel]
# 7                                       San Francisco
# 8                                                None
# 9                                                None
# 10                                           [, , , ]
# 11                                           [, , , ]
# 12
# 13
# 14  [Brian Chesky, CEO, Nathan Blecharczyk, CTO, J...
# 15  [Brian Chesky is the co-founder, Head of Commu...
# 16                                             [, , ]
# 17                                             [, , ]

# %%
scraper.step3()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]ERROR:scraperai:Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[text()='Show 1,000+ companies']"}
#   (Session info: chrome=124.0.6367.78)
# Stacktrace:
# 0   chromedriver                        0x0000000107b5ca18 chromedriver + 5216792
# 1   chromedriver                        0x0000000107b54653 chromedriver + 5183059
# 2   chromedriver                        0x00000001076c6527 chromedriver + 406823
# 3   chromedriver                        0x0000000107711ff2 chromedriver + 716786
# 4   chromedriver                        0x0000000107712181 chromedriver + 717185
# 5   chromedriver                        0x00000001077561d4 chromedriver + 995796
# 6   chromedriver                        0x000000010773472d chromedriver + 857901
# 7   chromedriver                        0x00000001077536bf chromedriver + 984767
# 8   chromedriver                        0x00000001077344a3 chromedriver + 857251
# 9   chromedriver                        0x0000000107704fe3 chromedriver + 663523
# 10  chromedriver                        0x000000010770592e chromedriver + 665902
# 11  chromedriver                        0x0000000107b1a930 chromedriver + 4946224
# 12  chromedriver                        0x0000000107b209e4 chromedriver + 4970980
# 13  chromedriver                        0x0000000107afb42e chromedriver + 4817966
# 14  chromedriver                        0x0000000107b214f9 chromedriver + 4973817
# 15  chromedriver                        0x0000000107aeb6b4 chromedriver + 4753076
# 16  chromedriver                        0x0000000107b43ba8 chromedriver + 5114792
# 17  chromedriver                        0x0000000107b43d67 chromedriver + 5115239
# 18  chromedriver                        0x0000000107b54273 chromedriver + 5182067
# 19  libsystem_pthread.dylib             0x00007ff80e5ee202 _pthread_start + 99
# 20  libsystem_pthread.dylib             0x00007ff80e5e9bab thread_start + 15
# Traceback (most recent call last):
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/scraperai/crawlers/selenium.py", line 77, in switch_page
#     self.click(pagination.xpath)
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/scraperai/crawlers/selenium.py", line 39, in click
#     elem = self.driver.find_element(By.XPATH, xpath)
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 831, in find_element
#     return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 440, in execute
#     self.error_handler.check_response(response)
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/venv/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py", line 245, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//button[text()='Show 1,000+ companies']"}
#   (Session info: chrome=124.0.6367.78)
# Stacktrace:
# 0   chromedriver                        0x0000000107b5ca18 chromedriver + 5216792
# 1   chromedriver                        0x0000000107b54653 chromedriver + 5183059
# 2   chromedriver                        0x00000001076c6527 chromedriver + 406823
# 3   chromedriver                        0x0000000107711ff2 chromedriver + 716786
# 4   chromedriver                        0x0000000107712181 chromedriver + 717185
# 5   chromedriver                        0x00000001077561d4 chromedriver + 995796
# 6   chromedriver                        0x000000010773472d chromedriver + 857901
# 7   chromedriver                        0x00000001077536bf chromedriver + 984767
# 8   chromedriver                        0x00000001077344a3 chromedriver + 857251
# 9   chromedriver                        0x0000000107704fe3 chromedriver + 663523
# 10  chromedriver                        0x000000010770592e chromedriver + 665902
# 11  chromedriver                        0x0000000107b1a930 chromedriver + 4946224
# 12  chromedriver                        0x0000000107b209e4 chromedriver + 4970980
# 13  chromedriver                        0x0000000107afb42e chromedriver + 4817966
# 14  chromedriver                        0x0000000107b214f9 chromedriver + 4973817
# 15  chromedriver                        0x0000000107aeb6b4 chromedriver + 4753076
# 16  chromedriver                        0x0000000107b43ba8 chromedriver + 5114792
# 17  chromedriver                        0x0000000107b43d67 chromedriver + 5115239
# 18  chromedriver                        0x0000000107b54273 chromedriver + 5182067
# 19  libsystem_pthread.dylib             0x00007ff80e5ee202 _pthread_start + 99
# 20  libsystem_pthread.dylib             0x00007ff80e5e9bab thread_start + 15
#
#   0%|          | 0/20 [00:03<?, ?it/s]
# Empty DataFrame
# Columns: []
# Index: []

# %%
scraper.crawler.driver.quit()
