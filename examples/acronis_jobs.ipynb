# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from local.steps import LocalScraperAI

# %%
url = 'https://www.acronis.com/bg-bg/careers/jobs/'
scraper = LocalScraperAI(url)

# %%
scraper.step1()
print(scraper.summary)
scraper.ipython_screenshot
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# Summary:
# Start url             https://www.acronis.com/bg-bg/careers/jobs/
# Page Type             WebpageType.CATALOG
# Pagination            Pagination using infinite scroll
# Total OpenAI cost, $  0.517
# <img width=600 src="data:image/png;base64,..." />

# %%
scraper.crawler.driver.quit()
