# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from local.steps import LocalScraperAI

# %%
url = 'https://techcrunch.com/category/cryptocurrency/'
scraper = LocalScraperAI(url)

# %%
scraper.step1()
print(scraper.summary)
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# Summary:
# Start url             https://techcrunch.com/category/cryptocurrency/
# Page Type             WebpageType.CATALOG
# Pagination            Pagination using button with xpath: //button[@class='load-more']
# Catalog Item          (card_xpath=//article[contains(@class, 'post-block')], url_xpath=//article[contains(@class, 'post-block')]//a[@class='post-block__title__link']/@href)
# Total OpenAI cost, $  0.196

# %%
scraper.ipython_screenshot
# Out:
# <img width=600 src="data:image/png;base64,..." />

# %%
scraper.step2()
print(scraper.summary)
scraper.ipython_screenshot
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# Summary:
# Start url             https://techcrunch.com/category/cryptocurrency/
# Page Type             WebpageType.CATALOG
# Pagination            Pagination using button with xpath: //*[@class='load-more']
# Catalog Item          (card_xpath=//article[contains(@class, 'post-block')], url_xpath=//article[contains(@class, 'post-block')]//a[@class='post-block__title__link']/@href)
# Fields                5 static, 0 dynamic
# Total OpenAI cost, $  0.212
# <img width=600 src="data:image/png;base64,..." />

# %%
scraper.static_fields_df
# Out:
#                name                                              xpath  \
# 0          Category  //div[@class='article__primary-category']/a/te...
# 1     Article Title          //h2[@class='post-block__title']/a/text()
# 2       Author Name  //span[@class='river-byline__authors']/span/a/...
# 3  Publication Time  //time[@class='river-byline__full-date-time']/...
# 4   Article Content         //div[@class='post-block__content']/text()
#
#                                                value
# 0                                            Fintech
# 1  After 6-year hiatus, Stripe to start taking cr...
# 2                                      Ingrid Lunden
# 3                    [7:55 PM GMT+3, April 25, 2024]
# 4  The company announced that it would start to l...

# %%
scraper.step3()
# Out:
#   0%|          | 1/200 [00:04<15:30,  4.68s/it]Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@class='load-more']"}
#   (Session info: chrome=124.0.6367.78)
# Stacktrace:
# 0   chromedriver                        0x000000010bcb0a18 chromedriver + 5216792
# 1   chromedriver                        0x000000010bca8653 chromedriver + 5183059
# 2   chromedriver                        0x000000010b81a527 chromedriver + 406823
# 3   chromedriver                        0x000000010b865ff2 chromedriver + 716786
# 4   chromedriver                        0x000000010b866181 chromedriver + 717185
# 5   chromedriver                        0x000000010b8aa1d4 chromedriver + 995796
# 6   chromedriver                        0x000000010b88872d chromedriver + 857901
# 7   chromedriver                        0x000000010b8a76bf chromedriver + 984767
# 8   chromedriver                        0x000000010b8884a3 chromedriver + 857251
# 9   chromedriver                        0x000000010b858fe3 chromedriver + 663523
# 10  chromedriver                        0x000000010b85992e chromedriver + 665902
# 11  chromedriver                        0x000000010bc6e930 chromedriver + 4946224
# 12  chromedriver                        0x000000010bc749e4 chromedriver + 4970980
# 13  chromedriver                        0x000000010bc4f42e chromedriver + 4817966
# 14  chromedriver                        0x000000010bc754f9 chromedriver + 4973817
# 15  chromedriver                        0x000000010bc3f6b4 chromedriver + 4753076
# 16  chromedriver                        0x000000010bc97ba8 chromedriver + 5114792
# 17  chromedriver                        0x000000010bc97d67 chromedriver + 5115239
# 18  chromedriver                        0x000000010bca8273 chromedriver + 5182067
# 19  libsystem_pthread.dylib             0x00007ff80e5ee202 _pthread_start + 99
# 20  libsystem_pthread.dylib             0x00007ff80e5e9bab thread_start + 15
# Traceback (most recent call last):
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/scraperai/crawlers/selenium.py", line 77, in switch_page
#     self.click(pagination.xpath)
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/scraperai/crawlers/selenium.py", line 39, in click
#     elem = self.driver.find_element(By.XPATH, xpath)
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 831, in find_element
#     return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/venv/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 440, in execute
#     self.error_handler.check_response(response)
#   File "/Users/iakov/Documents/PycharmProjects/scraperai/venv/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py", line 245, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@class='load-more']"}
#   (Session info: chrome=124.0.6367.78)
# Stacktrace:
# 0   chromedriver                        0x000000010bcb0a18 chromedriver + 5216792
# 1   chromedriver                        0x000000010bca8653 chromedriver + 5183059
# 2   chromedriver                        0x000000010b81a527 chromedriver + 406823
# 3   chromedriver                        0x000000010b865ff2 chromedriver + 716786
# 4   chromedriver                        0x000000010b866181 chromedriver + 717185
# 5   chromedriver                        0x000000010b8aa1d4 chromedriver + 995796
# 6   chromedriver                        0x000000010b88872d chromedriver + 857901
# 7   chromedriver                        0x000000010b8a76bf chromedriver + 984767
# 8   chromedriver                        0x000000010b8884a3 chromedriver + 857251
# 9   chromedriver                        0x000000010b858fe3 chromedriver + 663523
# 10  chromedriver                        0x000000010b85992e chromedriver + 665902
# 11  chromedriver                        0x000000010bc6e930 chromedriver + 4946224
# 12  chromedriver                        0x000000010bc749e4 chromedriver + 4970980
# 13  chromedriver                        0x000000010bc4f42e chromedriver + 4817966
# 14  chromedriver                        0x000000010bc754f9 chromedriver + 4973817
# 15  chromedriver                        0x000000010bc3f6b4 chromedriver + 4753076
# 16  chromedriver                        0x000000010bc97ba8 chromedriver + 5114792
# 17  chromedriver                        0x000000010bc97d67 chromedriver + 5115239
# 18  chromedriver                        0x000000010bca8273 chromedriver + 5182067
# 19  libsystem_pthread.dylib             0x00007ff80e5ee202 _pthread_start + 99
# 20  libsystem_pthread.dylib             0x00007ff80e5e9bab thread_start + 15
#
#  10%|█         | 20/200 [00:04<00:42,  4.25it/s]
#     Category                                      Article Title  \
# 0    Fintech  After 6-year hiatus, Stripe to start taking cr...
# 1   Startups  Carv raises $10M Series A to help gamers monet...
# 2       Apps  Block lets Square merchants convert a part of ...
# 3   Security  Security engineer jailed for 3 years for $12M ...
# 4   Startups  Kiki World, a beauty brand that uses web3 for ...
# 5       None  Nine crypto VCs on why Q1 investments were so ...
# 6     Crypto  The AI world needs more data transparency and ...
# 7     Crypto  TechCrunch Minute: Sam Bankman-Fried’s sentenc...
# 8     Crypto  SBF’s prison sentence marks the end of the cry...
# 9     Crypto  Sam Bankman-Fried gets 25 years in prison for ...
# 10    Crypto  SBF sentenced, Worldcoin hit with another ban ...
# 11    Crypto  0G Labs launches with whopping $35M pre-seed t...
# 12    Crypto  Web3 investment firm Borderless Capital acquir...
# 13   Privacy  Worldcoin hit with another ban order in Europe...
# 14    Crypto  A new web3 network is being built right now th...
# 15    Crypto  Solana memecoin hype continues, Backpack’s bet...
# 16    Crypto  Rails launches with $6.2M round for its decent...
# 17    Crypto  Crypto exchange OKX ceases services in India; ...
# 18    Crypto  TechCrunch Minute: Solana is ushering in a new...
# 19      None  How crypto exchange Backpack climbed its way t...
#
#                         Author Name                  Publication Time  \
# 0                     Ingrid Lunden   [7:55 PM GMT+3, April 25, 2024]
# 1                         Kate Park   [4:00 PM GMT+3, April 25, 2024]
# 2                        Ivan Mehta   [5:00 PM GMT+3, April 24, 2024]
# 3     Lorenzo Franceschi-Bicchierai   [7:39 PM GMT+3, April 12, 2024]
# 4                     Marina Temkin    [3:00 PM GMT+3, April 9, 2024]
# 5                 Jacquelyn Melinek   [9:28 PM GMT+3, March 29, 2024]
# 6                 Jacquelyn Melinek   [8:00 PM GMT+3, March 29, 2024]
# 7                      Alex Wilhelm   [7:00 PM GMT+3, March 29, 2024]
# 8                       Matt Rosoff   [3:13 AM GMT+3, March 29, 2024]
# 9                 Jacquelyn Melinek  [10:42 PM GMT+3, March 28, 2024]
# 10                Jacquelyn Melinek  [10:00 PM GMT+3, March 28, 2024]
# 11                Jacquelyn Melinek   [4:00 PM GMT+3, March 26, 2024]
# 12                        Kate Park   [3:49 PM GMT+3, March 26, 2024]
# 13                    Natasha Lomas   [3:36 PM GMT+3, March 26, 2024]
# 14                Jacquelyn Melinek  [10:21 PM GMT+3, March 21, 2024]
# 15                Jacquelyn Melinek  [10:00 PM GMT+3, March 21, 2024]
# 16                Jacquelyn Melinek   [7:00 PM GMT+3, March 21, 2024]
# 17                     Manish Singh   [1:52 PM GMT+3, March 21, 2024]
# 18  [Alex Wilhelm, Yashad Kulkarni]   [7:00 PM GMT+3, March 20, 2024]
# 19                Jacquelyn Melinek   [7:17 PM GMT+3, March 19, 2024]
#
#                                       Article Content
# 0   The company announced that it would start to l...
# 1   Carv, a data layer platform that lets web3 gam...
# 2   Block, the company behind Square, Cash App and...
# 3   Shakeeb Ahmed, a cybersecurity engineer convic...
# 4   If you think that choosing a nail polish color...
# 5   If the 2023 crypto venture landscape was an ic...
# 6   As AI proliferates and things on the internet ...
# 7   After a lengthy trial and conviction, we final...
# 8   Nearly everything else that’s being built on o...
# 9   Before sentencing, Bankman-Fried acknowledged ...
# 10  Welcome to TechCrunch Crypto, formerly known a...
# 11  As the crypto space heats back up, so has fund...
# 12  Borderless Capital, an investment firm that sp...
# 13  Controversial crypto biometrics venture Worldc...
# 14  Many of the people building web3 feel like the...
# 15  Welcome to TechCrunch Crypto. This week, Starb...
# 16  Rails, a decentralized crypto exchange, has ra...
# 17  Updated at 12.16am IST, March 23: KuCoin said ...
# 18  Blockchain is back and Bitcoin is hot, the Eth...
# 19  Backpack’s founders, who are building a crypto...

# %%
scraper.crawler.driver.quit()
