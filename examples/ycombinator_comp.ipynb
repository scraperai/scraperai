# %%
# %load_ext autoreload
# %autoreload 2

# %%
from local.steps import LocalScraperAI

# %%
url = 'https://www.ycombinator.com/companies' # Enter the URL of the website
scraper = LocalScraperAI(url)

# %%
scraper.step1()
print(scraper.summary)
scraper.ipython_screenshot
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# Summary:
# Start url             https://www.ycombinator.com/companies
# Page Type             WebpageType.CATALOG
# Pagination            Pagination using button with xpath: //div[text()='Loading more...']
# Catalog Item          (card_xpath=//a[contains(@class, '_company_99gj3_339')], url_xpath=//a[contains(@class, '_company_99gj3_339')]/@href)
# Total OpenAI cost, $  0.012
# <img width=600 src="data:image/png;base64,..." />

# %%
scraper.step2()
scraper.ipython_screenshot
# Out:
#  /\_/\
# ( ^.^ )
#  > ^ <
#  DONE!
# <img width=600 src="data:image/png;base64,..." />

# %%
scraper.static_fields_df
# Out:
#            name                                              xpath  \
# 0  Company Name                 //span[@class='_coName_99gj3_454']
# 1      Location             //span[@class='_coLocation_99gj3_470']
# 2   Description          //span[@class='_coDescription_99gj3_479']
# 3         Batch  //a[@class='_tagLink_99gj3_1024'][1]/span[@cla...
# 4    Industry 1  //a[@class='_tagLink_99gj3_1024'][2]/span[@cla...
# 5    Industry 2  //a[@class='_tagLink_99gj3_1024'][3]/span[@cla...
#
#                                    value
# 0                                 Airbnb
# 1                 San Francisco, CA, USA
# 2  Book accommodations around the world.
# 3                                    W09
# 4                               Consumer
# 5            Travel, Leisure and Tourism

# %%
scraper.dynamic_fields_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(scraper.summary)
# Out:
# Summary:
# Start url             https://www.ycombinator.com/companies
# Page Type             WebpageType.CATALOG
# Pagination            Pagination using button with xpath: //div[text()='Loading more...']
# Catalog Item          (card_xpath=//a[contains(@class, '_company_99gj3_339')], url_xpath=//a[contains(@class, '_company_99gj3_339')]/@href)
# Fields                6 static, 0 dynamic
# Total OpenAI cost, $  0.012

# %%
scraper.step3()
# Out:
# 240it [00:21, 11.01it/s]
#          Company Name                         Location  \
# 0              Airbnb           San Francisco, CA, USA
# 1           Instacart           San Francisco, CA, USA
# 2            DoorDash           San Francisco, CA, USA
# 3            Coinbase           San Francisco, CA, USA
# 4             Dropbox           San Francisco, CA, USA
# ..                ...                              ...
# 235  Mighty Buildings                 Oakland, CA, USA
# 236               Joy           San Francisco, CA, USA
# 237           Delphia              Toronto, ON, Canada
# 238    Treasury Prime           San Francisco, CA, USA
# 239            Duffel  London, England, United Kingdom
#
#                                            Description  Tags
# 0                Book accommodations around the world.  None
# 1          Marketplace for grocery delivery and pickup  None
# 2                                 Restaurant delivery.  None
# 3              Buy, sell, and manage cryptocurrencies.  None
# 4                 Backup and share files in the cloud.  None
# ..                                                 ...   ...
# 235  3D printing beautiful, high-quality, and susta...  None
# 236             The platform for all your life events.  None
# 237  Delphia — building at the intersection of cons...  None
# 238  Embedded banking software platform and marketp...  None
# 239               The complete toolkit to sell travel.  None
#
# [240 rows x 4 columns]

# %%
scraper.crawler.driver.quit()
